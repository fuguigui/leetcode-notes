# %% [markdown]
# #  Leetcode高频
#
# https://www.1point3acres.com/bbs/thread-898661-1-1.html
#
# https://www.1point3acres.com/bbs/thread-892997-1-1.html
#
# - [(hard)1293 Shortest Path in a Grid With Obstacles Elimination](https://leetcode.cn/problems/shortest-path-in-a-grid-with-obstacles-elimination)
#     - 思路：最短路径：BFS，使用 带状态的BFS
# - [(medium)2096 Step by Step Directions From a Binary Tree Node to Another](https://leetcode.cn/problems/step-by-step-directions-from-a-binary-tree-node-to-another)
#     - 思路一：递归，一次性找到路径，参考236最近公共祖先
#     - 思路二：BFS+双路径，处理相同前缀
# - [(medium)366 Find Leaves of Binary Tree](https://leetcode.cn/problems/find-leaves-of-binary-tree)
#     - 思路：dummy head + dfs
# - 🌟[(hard)818 Race Car](https://leetcode.cn/problems/race-car)
#     - 思路一：BFS+状态
# - [(medium)2128 Remove All Ones With Row and Column Flips](https://leetcode.cn/problems/remove-all-ones-with-row-and-column-flips)
#     - 思路：遍历，一共m+n种操作，需要的话都做一遍，最后看看成不成
#     - 相似例题861:https://leetcode.cn/problems/score-after-flipping-matrix/
#
# - [(medium)2115 Find All Possible Recipes From Given Supplies](https://leetcode.cn/problems/find-all-possible-recipes-from-given-supplies)
#     - 思路：建图+拓扑排序
# - [(medium)150 Evaluate Reverse Polish Notation](https://leetcode.cn/problems/evaluate-reverse-polish-notation)
#     - 栈的基本应用
# - [(medium)539 Minimum Time Difference](https://leetcode.cn/problems/minimum-time-difference)
#     - 哈希桶排序
# - [(medium)1048 Longest String Chain](https://leetcode.cn/problems/longest-string-chain)
#     - 思路一：动态规划
#     - 思路二：森林+bfs+memo剪枝，时间复杂度更低，没有NlogN
# - [(medium)1146 Snapshot Array](https://leetcode.cn/problems/snapshot-array)
#     - 思路：单个数字自己维护：哈希表+数组用于二分查找。
#
# - [(medium)2013 Detect Squares](https://leetcode.cn/problems/detect-squares)
#     - 考点：哈希表的运用
# - 🌟[(medium)1937 Maximum Number of Points With Cost](https://leetcode.cn/problems/maximum-number-of-points-with-cost)
#     - 考点：动态规划：相对拆为绝对。
# - [(medium)2034 Stock Price Fluctuation](https://leetcode.cn/problems/stock-price-fluctuation)
#     - 思路一：两个堆，哈希表+最大时间戳 + 延迟删除
# - [(hard)552 Student Attendance Record II](https://leetcode.cn/problems/student-attendance-record-ii)
#     - 考点：动态规划：分类讨论
# - 🌟[(medium)2178 Maximum Split of Positive Even Integers](https://leetcode.cn/problems/maximum-split-of-positive-even-integers)
#     - 思路一：转化为0-1背包。结果超时。复杂度是N根号N的。
#     - 思路二：上述思路可能会超时，实际上因为数字最大可能是10的10次方，不能用一般N或logN的复杂度，都会超时，最后发现有O(1)解法的数学公式。想法就是（先去掉偶数）用高斯求和公式来划分0-N，如果N恰好等于1到j的求和，则数字最多为j，否则总可以j-1个数字来表示，j是大于N的第一个高斯和的位置。比如，数字可划分为j=1的时候，1，j=2的时候3，j=3的时候6，j=4的时候为10，如果N=8，就找到10=1+2+3+4，并去掉数字10-8=2，即用1+3+4，这3个数字来表示。数量是最多的。
# - 🌟[(hard)1610 Maximum Number of Visible Points](https://leetcode.cn/problems/maximum-number-of-visible-points)
#     - 思路：坐标转角度，排序，滑动窗口。细节也太多了！！
# - [(medium)833 Find and Replace In String](https://leetcode.cn/problems/find-and-replace-in-string)
#     - 思路一：数组，一对一改为一对多
#     - 思路二：index逆序排序
# - [(hard)843 Guess The Word](https://leetcode.cn/problems/guess-the-word)
#     - 思路：贪心+建图+随机化
#
# 06.17
# - [(hard)2158 Amount of New Area Painted Each Day](https://leetcode.cn/problems/amount-of-new-area-painted-each-day)
#
#     There is a long and thin painting that can be represented by a number line. You are given a 0-indexed 2D integer array paint of length n, where paint[i] = [starti, endi]. This means that on the ith day you need to paint the area between starti and endi.
#
#     Painting the same area multiple times will create an uneven painting so you only want to paint each area of the painting at most once.
#
#     Return an integer array worklog of length n, where worklog[i] is the amount of new area that you painted on the ith day.
#     - 会议室安排问题，跳过重复的子区间
#
# https://songhayoung.github.io/2022/02/24/PS/LeetCode/amount-of-new-area-painted-each-day/
# - [(easy)359 Logger Rate Limiter](https://leetcode.cn/problems/logger-rate-limiter)
#     [come from](https://www.cnblogs.com/grandyang/p/5592635.html)
# Design a logger system that receive stream of messages along with its timestamps, each message should be printed if and only if it is not printed in the last 10 seconds.
#
# Given a message and a timestamp (in seconds granularity), return true if the message should be printed in the given timestamp, otherwise returns false.
#
# It is possible that several messages arrive roughly at the same time.
#     - 思路：乍一看是个滑动窗口题目，实际上是个哈希表（滑动窗口的lazy update）。key是消息，value是时间戳。对于要打印的时间戳，查询哈希表。不在，返回true，在时间戳差距大于10，返回true，否则返回false。将value置为新的时间戳。空间复杂度：消息的个数，会不停增长。可以定期清理消息。
#     - 思路二：滑动窗口，就根据时间戳不停地移动窗口，用一个计数器，计数窗口里有什么消息，即对应的次数。每次移出的时候，更改对应消息的计数器。查询的时候，看消息是否在计数器中，不在，返回true，将消息加入计数器。否则，返回false。空间复杂度：需要维护窗口长度的数组，此外，维护可能是窗口长度的计数器。
#
# - [(hard)68 Text Justification](https://leetcode.cn/problems/text-justification)
#     - 考点：细节题？？
# - [(hard)1284 Minimum Number of Flips to Convert Binary Matrix to Zero Matrix](https://leetcode.cn/problems/minimum-number-of-flips-to-convert-binary-matrix-to-zero-matrix)
#     - 考点：位运算 + bfs+memo
# - [(medium)528 Random Pick With Weight](https://leetcode.cn/problems/random-pick-with-weight)
#     - 思路：前缀和+二分
#
# - [(hard)1240 Tiling A Rectangle With The Fewest Squares](https://leetcode.cn/problems/tiling-a-rectangle-with-the-fewest-squares)
#     - 考点：注意题目的规模。dfs+记忆化搜索
# - [(hard)660 Remove 9](https://leetcode.cn/problems/remove-9)[link](https://www.cnblogs.com/grandyang/p/8261714.html)
#     - 我的思路：分组+9进制，google doc
#
# - [(medium)792 Number of Matching Subsequences](https://leetcode.cn/problems/number-of-matching-subsequences)
#     - 思路一：桶：处理剩余字符。复杂度：O(len(s)* W), W is the number of words
#
# - [(medium)652 Find Duplicate Subtrees](https://leetcode.cn/problems/find-duplicate-subtrees)
#     - dfs + 序列化树
# - [(hard)1948 Delete Duplicate Folders In System](https://leetcode.cn/problems/delete-duplicate-folders-in-system)
#     - 难点在于复杂，细节处理。字典树，序列化表示，注意序列化表示的唯一性。
#
# 06.18
# - [(medium)562 Longest Line of Consecutive One in Matrix](https://leetcode.cn/problems/longest-line-of-consecutive-one-in-matrix)
#     - 思路：4个方向的dp即可
# - [(hard)302 Smallest Rectangle Enclosing Black Pixels](https://leetcode.cn/problems/smallest-rectangle-enclosing-black-pixels)
#     - 思路：BFS或DFS，找x y的最大值和最小值
#
# - [(medium)1423 Maximum Points You Can Obtain From Cards](https://leetcode.cn/problems/maximum-points-you-can-obtain-from-cards)
#     - 看似递归，实则滑动窗口
# - [(medium)418 Setence Screen Fitting](https://leetcode.cn/problems/sentence-screen-fitting)
# - [(hard)489 Robot Room Cleaner](https://leetcode.cn/problems/robot-room-cleaner)
# - [(medium)777 Swap Adjacent in LR String](https://leetcode.cn/problems/swap-adjacent-in-lr-string)
# - [(hard)715 Range Module](https://leetcode.cn/problems/range-module)
# - [(medium)1554 Strings Differ By One Character](https://leetcode.cn/problems/strings-differ-by-one-character)
# - [(hard)778 Swim In Rising Water](https://leetcode.cn/problems/swim-in-rising-water)
# - [(medium)939 Minimum Area Rectangle](https://leetcode.cn/problems/minimum-area-rectangle)
#
# 06.19
# - [(medium)2007 Find Original Array From Doubled Array](https://leetcode.cn/problems/find-original-array-from-doubled-array)
#
# - [(hard)329 Longest Increasing Path In a Matrix](https://leetcode.cn/problems/longest-increasing-path-in-a-matrix)
# - [(easy)720 Longest Word In Dictionary](https://leetcode.cn/problems/longest-word-in-dictionary)
# - [(hard)839 Similar String Groups](https://leetcode.cn/problems/similar-string-groups)
# - [(hard)1397 Find All Good Strings](https://leetcode.cn/problems/find-all-good-strings)
# - [(hard)920 Number of Music Playlists](https://leetcode.cn/problems/number-of-music-playlists)
# - [(hard)664 Strange Printer](https://leetcode.cn/problems/strange-printer)
# - [(medium)1218 Longest Arithmetic Subsequence of Given Difference](https://leetcode.cn/problems/longest-arithmetic-subsequence-of-given-difference)
# - [(hard)2092 Find All People With Secret](https://leetcode.cn/problems/find-all-people-with-secret)
# - [(hard)975 Odd Even Jump](https://leetcode.cn/problems/odd-even-jump)
#
#
# - [(hard)642 Design Search Autocomplete System](https://leetcode.cn/problems/design-search-autocomplete-system)
# - [(medium)299 Bulls And Cows](https://leetcode.cn/problems/bulls-and-cows)
# - [(medium)794 Valid Tic Tac Toe State](https://leetcode.cn/problems/valid-tic-tac-toe-state)
# - [(medium)388 Longest Absolute File Path](https://leetcode.cn/problems/longest-absolute-file-path)
# - [(medium)1477 Find Two Non-Overlapping Subarrays Each With Target Sum](https://leetcode.cn/problems/find-two-non-overlapping-sub-arrays-each-with-target-sum)
# - [(medium)1834 Single Threaded CPU](https://leetcode.cn/problems/single-threaded-cpu)
# - [(medium)394 Decode String](https://leetcode.cn/problems/decode-string)
# - [(medium)1631 Path With Minimum Effort](https://leetcode.cn/problems/path-with-minimum-effort)
# - [(hard)2188 Minimum Time to Finish the Race](https://leetcode.cn/problems/minimum-time-to-finish-the-race)
# - [(medium)900 RLE Iterator](https://leetcode.cn/problems/rle-iterator)
# - [(medium)2162 Minimum Cost to Set Cooking Time](https://leetcode.cn/problems/minimum-cost-to-set-cooking-time)
#
# - [(hard)1153 String Transforms Into Another String](https://leetcode.cn/problems/string-transforms-into-another-string)
# - [(medium)837 New 21 Game](https://leetcode.cn/problems/new-21-game)
# - [(medium)1882 Process Tasks Using Servers](https://leetcode.cn/problems/process-tasks-using-servers)
# - [(medium)202 Happy Number](https://leetcode.cn/problems/happy-number)
# - [(medium)1055 Shortest Way to Form String](https://leetcode.cn/problems/shortest-way-to-form-string)
# - [(hard)2242 Maximum Score of a Node Sequence](https://leetcode.cn/problems/maximum-score-of-a-node-sequence)
# - [(medium)56 Merge Intervals](https://leetcode.cn/problems/merge-intervals)
# - [(hard)1632 Rank Transform of a Matrix](https://leetcode.cn/problems/rank-transform-of-a-matrix)
# - [(medium)1277 Count Square Submatrices With All Ones](https://leetcode.cn/problems/count-square-submatrices-with-all-ones)
# - [(medium)1509 Minimum Difference Between Largest And Smallest Value In Three Moves](https://leetcode.cn/problems/minimum-difference-between-largest-and-smallest-value-in-three-moves)
#
# - [(medium)1102 Path With Maximum Minimum Value](https://leetcode.cn/problems/path-with-maximum-minimum-value)
# - [(hard)465 Optimal Account Balancing](https://leetcode.cn/problems/optimal-account-balancing)
# - [(medium)1514 Path With Maximum Probability](https://leetcode.cn/problems/path-with-maximum-probability)
# - [(easy)551 Student Attendance Record I](https://leetcode.cn/problems/student-attendance-record-i)
# - [(hard)753 Cracking the Safe](https://leetcode.cn/problems/cracking-the-safe)
# - [(easy)1592 Rearrange Spaces Between Words](https://leetcode.cn/problems/rearrange-spaces-between-words)
# - [(hard)233 Number of Digit One](https://leetcode.cn/problems/number-of-digit-one)
# - [(hard)471 Encode String With Shortest Length](https://leetcode.cn/problems/encode-string-with-shortest-length)
# - [(hard)1263 Minimum Moves to Move a Box to Their Target Location](https://leetcode.cn/problems/minimum-moves-to-move-a-box-to-their-target-location)
# - [(medium)2083 Substrings That Begin And End With The Same Letter](https://leetcode.cn/problems/substrings-that-begin-and-end-with-the-same-letter)
# - [(easy)2103 Rings and Rods](https://leetcode.cn/problems/rings-and-rods)

# %% [markdown]
# # 面经
#
#
# 我这周被考了线段树和动态规划：接亲小游戏啊 刁难伴郎 哈哈哈哈
#
# 我遇到了union find
#
# 月初面的，三轮coding两轮dp，湿了智
#
# dynamic programming 的题目可以用 DFS + memoization 来做
#
# 我认识一个狗家的人说他喜欢出看起来像DP的greedy题。。。。
#
# 第二次很可惜，我说我可以dfs+memoization，面试官说i'm not interested in your dfs with memoization. we need time/space optimized，我最后写出来的有bug。
#
# - 利口散令起不过不更新，找最大，一共就写了个线段树，我用的array实现的，被问优缺点，小哥有点凶
#
# - 给一组log有任务id，时间，开始或者结束，再给一个timeout，找第一个timeout的任务，log里不是所有开始的id都有结束log，好像见过类似题不记得了号了，follow up是timeout不是constant和输入是数据流怎么办
#
#
# 一开始的条件timeout是固定的，比如4，对所有log一样，log是按时间排好序，所以不用排序只要一个queue查是否timeout，一个hashset记录还没有结束的task，如果在queue里timeout的task也在hashset那就找到结果了
# 比如输入是(id, timestamp, event), timeout = 3
# (1, 0, start) (2,1,start) (1,2,end) (2,8,end) (3,10,start)
# task2是第一个timeout的，而且要求是越早找到越好，task3这种没有end的也算timeout，follow up的timeout会对每个task不一样，用heap代替queue就行，stream输入的情况下这个方法也适用
#
# - 给一串floder，有它的id，名字，parent，打印从folder到根的路径，需要检测环和memorization优化复杂度还有各种edge case
#
# 输入大概这样 (id, displayName, parent)
# folder(1,"folder1",-1)
# folder(2,"folder2",1)
# folder(4,"folder4",2)
# folder(3,"folder3",-1)
# 输出就是"folder1","folder1/folder2","folder1/folder2/folder4","folder3"
# id一定唯一，名字是否唯一不重要，根的parent是-1，brute force就是build graph然后每个folder向根扫，复杂度o(n^2)，用**递归dfs+memo**是o(n)，就是把folder的结果存起来，比如f1->f2->f3-> ...f100, 如果f2已经做过了，找f1的时候直接重复利用可以避免遍历，没做过就递归找f2，和dp top down思路一样，所以每个folder只走一遍
#
# - round 1: graph dfs, 套了一个马甲，前提每个graph node 分布在不同server, 不能用global memory，要求写算法每个node遍历一次
#
# - round 2: 给一组数A，问能不能找到俩数，满足index |i-j| <= a, value |A - A[j]| <= b... 楼主知道是sliding window，但只会暴力解，感谢人美心善的国人小姐姐提示用BST优化window里的操作
#
# - 523 变种，Follow up 需要O(n)完成。
#
# - 315,变种，计算自己的前面smaller number ，Follow up 需要用Binary Search完成
#
# - 747，Follow up 需要O(n)完成
#
# - input一个长度为偶数的数组，odd位置是重复次数，even位置是数字，设计一个iterator 的next() function，return 下一个应该print的数字比如[1,2,3,4] 用iterator遍历完应该输出 2,2,4,4,4
#   时间空间复杂度要求constant
#   用一个指针就能完成，follow up是当遇到次数为0的时候，next()要返回上一个遇到的数字
#
# - 如果问最短，最少，BFS
#
#   如果问连通性，静态就是 DFS,BFS，动态就 UF
#
#   如果问依赖性就 topo sort
#
#   DAG 的问题就 dfs+memo
#
#   矩阵和 Array 通常都是 DP
#
#   问数量的通常都是 DP
#
#   问是否可以，也很有可能 DP
#
#   求所有解的，基本 backtracking
#
#   排序总是可以想一想的
#
#   万事总可以想HashMap
#
#   找规律试试Stack
#
#   作者：Joshua Li
#   🌟链接：https://www.zhihu.com/question/24099873/answer/455904365
#   来源：知乎
#   著作权归作者所有。商业转载请联系作者获得授权，非商业转载请注明出处。
#
#
# https://www.1point3acres.com/bbs/thread-898915-1-1.html
#
# 1. Check Directions
#   N, S, E, W表示东南西北, 1N2表示1在2的北边 1NW2 ‍‌‌‌‌‍‍‌‍‌‌‌‍‌‌‍‌‍‌‍表示1 在2的西南 给一个序列，检查是否合法["1N2", "3N4", "4NW5"]
#   以南北和东西分两个Topological sort解决
#
# 2. Closest Cafe for everyone
#   有一群好朋友要在学校里找个距离所有人最近的咖啡厅，前提是必须让所有的好朋友都能到达。Friends array: [1,2] Cafe array: [4,5]. 给一个二维数组代表图里面连接的边：( (1,2) , (1,5) , (2,4) ), 返回距离最近的咖啡厅。
#   以每个咖啡店为起点bfs，记录下距离，最后选取距离最短的咖啡店
#
# 3. Restaurant waiting list
#   Build a data structure to perform three operations (Restaurant is full initially):
#
#   1. waitList (string customer_name, int table_size):
#     Add customer with given name and table size they want to book into the waitlist
#   2. leave (string customer_name):
#     Customer wants to leave the waitlist so remove them.
#   3. serve (int table_size):
#     This means restaurant now has a free table of size equal to table_size. Find the best customer to serve from waitlist
#     Best Customer: Customer whose required size is less than or equal to the table_size. If multiple customers are matching use first come first serve.
#     For e.g. if waitlist has customers with these table requirements => [2, 3, 4, 5, 5, 7] and restaurant is serving table_size = 6 then best customer is index 3 (0-based indexing).
#     TreeMap<Integer, Deque<String>> key是人数size，value是一个存储人名的队列
#     HashMap<String, Integer> key是人名，value是人数size
#   4. Temperature
#     Given a Temperature Manager class, with functions recordTemp(int temp); and getMaxTemp(); You need to record the temperature when a new temp comes in, and get the max within the last 24 hours.
#     单调栈即可
#   5. lc2242: [力扣](https://leetcode.cn/problems/maximum-score-of-a-node-sequence/)
#
# https://www.1point3acres.com/bbs/thread-898237-1-1.html
#
# 第二轮：add and remove points from the matrix and print out the boundary box to encompass all points
# Leetcode Discussion: https://leetcode.com/discuss/int ... le-Phone-interview-(reject)/943347
#
# 第三轮：Design waitlist system, add to waitlist, remove from waitlist, sit someone from waitlist
# Leetcode Discussion: https://leetcode.com/discuss/int ... 205;‌‍n
#
# 第四轮：Flip row or column to close all lights
# Leetcode Discussion: https://leetcode.com/discuss/int ... s-out-puzzle/397815
#
# https://www.1point3acres.com/bbs/thread-898295-1-1.html
#
# 第一轮：国人大哥
# 给了一个array = [(‘d’, ‘>’, ‘e’), (‘e’, ‘>’, ‘f’)] ，里面每个元素包含三个部分。这三个部分合起来表示一个不等式运算。问把这些不等运算放在一起之后，会不会形成一个valid的不等式？如果能就return true；否则false。
# 例如这里的 d > e, e > f → d > e > f是个valid的不等式，所以return true
# 又比如给了一个 d > e, e > f, f > d → return false。因为不可能同时存在d > f, f > d
#
# 我一开始想的是根据array建一个graph，然后看graph里面有没有cycle，那就是要用union find。但面试官说不需要union find，提示了两种遍历方法。我给了bfs，但似乎也不是很好的solution。于是就改用了dfs。然后就要求我优化一下时间。提出了用memoization。最后时间虽然很赶，但勉强写给出了dfs+memo的solution，分析了下复杂度就没时间了。这轮表现挺不好的，主要是一开始的思路跑偏了。也是感谢国人面试官大哥的hints。LC course schedule。 最优解应该是topo sort
#
# 第二轮：黑人老哥
# 给一个target单词，一个guess单词，如果位置完全匹配是G，字母匹配但是位置不匹配是Y，否则是R。如果有多个可以匹配为Y的，则把index最小的匹配成Y，其他的还是R，然后输出结果的string。比如BACD和CAGE，就输出YGRR‍‍‌‍‌‍‌‍‍‍‍‌‌‍‌‌‌‍‍。follow up是如果给一个‍‌‍‍‌‌‌‍‌‌‌‍‍‍‌‌‍‍‌‍target和一堆guess，每一步要求前一步的guess是G的地方需要保持，前一步如果是Y的地方这一步必须要包含这个单词。输出这一堆guesses是不是全部valid。参见这个帖子：https://www.1point3acres.com/bbs/thread-896429-1-1.html
#
# 第三轮：国人小哥
# 给了一个值d，一个数据流stream = [-10, 4, 3, 10, 5, ...]，最后要return一个array，里面只有三个元素（可重复），使得每个元素之间的差都 <= d
# 例如这里就return [4,3,5] （顺序无所谓）
#
# https://www.1point3acres.com/bbs/thread-889795-1-1.html
#
# 1. 人美心善的白人小哥哥，给一个path string比如说“asdfghjkloiujkjhsgfrert” 再给a list of 世界上所有的 English words (有1000k左右)， 返回能被这个path cover的所有words. 一个word被path string cover的意思是 这个word是path的一部分但是不需要连续 比如说给的这个例子里的path string就可以cover ["ghost" , "alert" ...] 其中"ghost" 是因为 "asdfghjkloiujkjhsgfrert"; "alert"是因为 “asdfghjkloiujkjhsgfrert”。 这一题LZ很快想到了思路，写到中间卡了，面试官问了个问题引导了一下 (对我来说是很critical的提示)， 最后回答了时间复杂度。
#
# 2. 人美心善的棕人大叔，给一个array, in place删掉里面所有的'a'， 第二问是 删掉里面所有的'a' 同时如果遇到一个'b'就把这个 'b'替换成 'bee' 都是要in place 做。这一轮和大叔聊了好几种方法，实现了他想要的。
#
# 3. 人美心善的国人小姐姐，给一堆circle，每个circle都有[x坐标, y坐标, radius] 如果两个circle重叠说明两个circle在一个group，然后如果a 和 b在一个group, b和c在一个group，我们就说a b c 都在一个group。 第一问判断是不是所有的circle是一个group，写了code 口头跑了几个test cases。 follow up是总共有多少个groups，很快说了想法based on第一问，小姐姐同意写了code，但是n ^ 3 time complexity, 最后几分钟问有没有更优解，没答上来.. （这轮感谢小姐姐没有给red flag，其实清醒点想想n ^ 2的方法挺直接的，只是LZ当时脑子里都是怎么优化第一问的想法）
#
# 4. 人美心善的国人小哥哥，给一个word和a list of strings，判断是否match。 match条件是word的每一个char 都存在于list的一个string里 而且顺序不能错. 比如 word = "cat&qng, dfs, bfs, dfs + bfs, topology sort .. 有什么思路就先说，沟通为主，有时候面试官表现出不太满意，赶紧换思路。目的是写出他想要的结果，在他的评分系统里拿最高分，一般面试官也会想办法帮助你的；不需要一上来就target on最优解，当然如果有最优解，快快说出来。然后google主要看算法所以别说废话，保存体力。(别的公司我觉得可以酌情扯扯淡啥的）
#
#
# https://www.1point3acres.com/bbs/thread-897045-1-1.html
#
# 第二轮，国人小哥，
#
# 第一题，278强化版，找出所有bad commit。我在地里看过这题，但是一直没看到有人说明白题意，所以这里详细说下。简单来说，input是两个integer，low和high，代表的是一开始的commit和最后的commit。你还有一个API isWorse(a, b) 可以比较两个commit a和b是不是恶化了。简单来说，就是给你一个数值单调递减的array（e.g. 999887776555322211），然后找出所有比前一个数字小的下标，只是这个下标不是0开始，而是low，然后最后是high，中间的下标数字连续。用binary search即可，如果binary search里右边没有比左边差，那么这个区间必定没有worse commit，直接返回，否则取中点，看中点是不是worse commit, 是的话加到answer里，再两边binary search
# 第二题351
#
# 第三轮，国人小姐姐
#
# 1293，套了个炸弹的壳，一开始是1个的情况，然后扩展到多个炸弹。BFS秒
# followup是炸弹无限制，问到达终点最少要多少个。用dijkstra解，用一个2darray 存每个点的optimal k，初始化为inf，然后起点的k为0。然后queue = [(0, start)]，每次heappop queue的一个点的时候看是不是可以把4个邻点的optimal k变小，如果可以的话就到heappush到queue。最终queue为空的时候终点的optimal k就是结果
#
# 第四轮，三姐
#
# 给一串数字（不连续，可大可小，可重复，可负数），写一个API生成这串数字的一个random permutation，生成过的不可再用，一开始就限定mem
#
# https://leetcode.com/problems/shuffle-an-array/
#
# 有宝藏无法collect，返回-1
# followup是宝藏被上锁了，有小写，小写是钥匙，大小写是对应的，譬如钥匙a可以解锁宝藏A。还是求到达终点的最短路径，还是要求收集所有的宝藏，但是要收集宝藏意味着先找到钥匙
# 这两题的思路都很像，就是基本的bfs套路，记录的状态除了访问过的格子，还有已经收集过的宝藏/钥匙，我是用bitmask做的，因为宝藏/钥匙 at most 26个，刚好可以用一个int来代表所有状态（估计这就是出题者的目的），而且宝藏的字母不是连续的，也就是说可能会有A，C但没有B的情况，bitmask刚好可以handle这种情况。碰到宝藏时要看有没有对应的钥匙，然后到终点时要判断是不是收集到所有的宝藏。
